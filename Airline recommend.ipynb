# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('British_Airway_Review.csv')
df
# Out:
#                                                 reviews                date  \
# 0     ✅ Trip Verified |  I had the most fantastic BA...     1st August 2023
# 1     ✅ Trip Verified |  Couldn’t book in online. Ar...      31st July 2023
# 2     ✅ Trip Verified | London Heathrow to Mumbai in...      31st July 2023
# 3     ✅ Trip Verified | Keflavík, Iceland to London ...      31st July 2023
# 4     ✅ Trip Verified | Terrible Experience with Bri...      29th July 2023
# ...                                                 ...                 ...
# 2495  Roundtrip with British Airways from Bangkok to...  12th November 2015
# 2496  Awful customer service. My wife and I have flo...  11th November 2015
# 2497  I travelled from London to Sydney via Singapor...  10th November 2015
# 2498  British Airways have just moved Cape Town flig...  10th November 2015
# 2499  Bengaluru to Heathrow. My first long haul flig...  10th November 2015
#
#              country       seat_type recommended  stars  \
# 0          Hong Kong  Business Class         yes      5
# 1     United Kingdom   Economy Class          no      3
# 2            Iceland  Business Class         yes      3
# 3            Iceland  Business Class         yes      5
# 4             Canada   Economy Class          no      5
# ...              ...             ...         ...    ...
# 2495        Thailand  Business Class          no      7
# 2496  United Kingdom  Business Class          no      3
# 2497       Australia     First Class         yes      5
# 2498  United Kingdom     First Class         yes      3
# 2499           India   Economy Class          no      3
#
#                       route type_of_traveller
# 0     Heathrow to Las Vegas    Family Leisure
# 1          Rome to Heathrow      Solo Leisure
# 2         Gatwick to Venice      Solo Leisure
# 3          London to Luanda    Couple Leisure
# 4        Denver to Heathrow    Family Leisure
# ...                     ...               ...
# 2495             BKK to LHR          Business
# 2496        London to Tampa    Couple Leisure
# 2497       London to Sydney    Couple Leisure
# 2498             LHR to CPT    Couple Leisure
# 2499             BLR to LHR          Business
#
# [2500 rows x 8 columns]

# %%
plt.figure(figsize=[30,20])
df['country'].value_counts().plot(kind='pie',autopct='%.0f%%')
# Out:
# <Axes: ylabel='country'>

# %%
plt.figure(figsize=[10,10])
df.route.value_counts().plot(kind='pie',autopct='%.0f%%')
# Out:
# <Axes: ylabel='route'>

# %%
plt.figure(figsize=[10,10])
df.seat_type.value_counts().plot(kind='pie',autopct='%.0f%%')
# Out:
# <Axes: ylabel='seat_type'>

# %%
plt.figure(figsize=[10,10])
df.stars.value_counts().plot(kind='pie',autopct='%.0f%%')
# Out:
# <Axes: ylabel='stars'>

# %%
plt.figure(figsize=[10,10])
df.type_of_traveller.value_counts().plot(kind='pie',autopct='%.0f%%')
# Out:
# <Axes: ylabel='type_of_traveller'>

# %%
df['day']=df['date'].str.split(' ',1).str[0]
df['month']=df['date'].str.split(' ',1).str[1].str[:2]
df['year']=df['date'].str.split(' ',1).str[1].str[-2:]
df
# Out:
# C:\Users\parsian\AppData\Local\Temp\ipykernel_4880\3783100416.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df['day']=df['date'].str.split(' ',1).str[0]
# C:\Users\parsian\AppData\Local\Temp\ipykernel_4880\3783100416.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df['month']=df['date'].str.split(' ',1).str[1].str[:2]
# C:\Users\parsian\AppData\Local\Temp\ipykernel_4880\3783100416.py:3: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df['year']=df['date'].str.split(' ',1).str[1].str[-2:]
#                                                 reviews                date  \
# 0     ✅ Trip Verified |  I had the most fantastic BA...     1st August 2023
# 1     ✅ Trip Verified |  Couldn’t book in online. Ar...      31st July 2023
# 2     ✅ Trip Verified | London Heathrow to Mumbai in...      31st July 2023
# 3     ✅ Trip Verified | Keflavík, Iceland to London ...      31st July 2023
# 4     ✅ Trip Verified | Terrible Experience with Bri...      29th July 2023
# ...                                                 ...                 ...
# 2495  Roundtrip with British Airways from Bangkok to...  12th November 2015
# 2496  Awful customer service. My wife and I have flo...  11th November 2015
# 2497  I travelled from London to Sydney via Singapor...  10th November 2015
# 2498  British Airways have just moved Cape Town flig...  10th November 2015
# 2499  Bengaluru to Heathrow. My first long haul flig...  10th November 2015
#
#              country       seat_type recommended  stars  \
# 0          Hong Kong  Business Class         yes      5
# 1     United Kingdom   Economy Class          no      3
# 2            Iceland  Business Class         yes      3
# 3            Iceland  Business Class         yes      5
# 4             Canada   Economy Class          no      5
# ...              ...             ...         ...    ...
# 2495        Thailand  Business Class          no      7
# 2496  United Kingdom  Business Class          no      3
# 2497       Australia     First Class         yes      5
# 2498  United Kingdom     First Class         yes      3
# 2499           India   Economy Class          no      3
#
#                       route type_of_traveller   day month year
# 0     Heathrow to Las Vegas    Family Leisure   1st    Au   23
# 1          Rome to Heathrow      Solo Leisure  31st    Ju   23
# 2         Gatwick to Venice      Solo Leisure  31st    Ju   23
# 3          London to Luanda    Couple Leisure  31st    Ju   23
# 4        Denver to Heathrow    Family Leisure  29th    Ju   23
# ...                     ...               ...   ...   ...  ...
# 2495             BKK to LHR          Business  12th    No   15
# 2496        London to Tampa    Couple Leisure  11th    No   15
# 2497       London to Sydney    Couple Leisure  10th    No   15
# 2498             LHR to CPT    Couple Leisure  10th    No   15
# 2499             BLR to LHR          Business  10th    No   15
#
# [2500 rows x 11 columns]

# %%
df['day']=df['day'].str.extract('(\d+)')
df
# Out:
#                                                 reviews                date  \
# 0     ✅ Trip Verified |  I had the most fantastic BA...     1st August 2023
# 1     ✅ Trip Verified |  Couldn’t book in online. Ar...      31st July 2023
# 2     ✅ Trip Verified | London Heathrow to Mumbai in...      31st July 2023
# 3     ✅ Trip Verified | Keflavík, Iceland to London ...      31st July 2023
# 4     ✅ Trip Verified | Terrible Experience with Bri...      29th July 2023
# ...                                                 ...                 ...
# 2495  Roundtrip with British Airways from Bangkok to...  12th November 2015
# 2496  Awful customer service. My wife and I have flo...  11th November 2015
# 2497  I travelled from London to Sydney via Singapor...  10th November 2015
# 2498  British Airways have just moved Cape Town flig...  10th November 2015
# 2499  Bengaluru to Heathrow. My first long haul flig...  10th November 2015
#
#              country       seat_type recommended  stars  \
# 0          Hong Kong  Business Class         yes      5
# 1     United Kingdom   Economy Class          no      3
# 2            Iceland  Business Class         yes      3
# 3            Iceland  Business Class         yes      5
# 4             Canada   Economy Class          no      5
# ...              ...             ...         ...    ...
# 2495        Thailand  Business Class          no      7
# 2496  United Kingdom  Business Class          no      3
# 2497       Australia     First Class         yes      5
# 2498  United Kingdom     First Class         yes      3
# 2499           India   Economy Class          no      3
#
#                       route type_of_traveller day month year
# 0     Heathrow to Las Vegas    Family Leisure   1    Au   23
# 1          Rome to Heathrow      Solo Leisure  31    Ju   23
# 2         Gatwick to Venice      Solo Leisure  31    Ju   23
# 3          London to Luanda    Couple Leisure  31    Ju   23
# 4        Denver to Heathrow    Family Leisure  29    Ju   23
# ...                     ...               ...  ..   ...  ...
# 2495             BKK to LHR          Business  12    No   15
# 2496        London to Tampa    Couple Leisure  11    No   15
# 2497       London to Sydney    Couple Leisure  10    No   15
# 2498             LHR to CPT    Couple Leisure  10    No   15
# 2499             BLR to LHR          Business  10    No   15
#
# [2500 rows x 11 columns]

# %%
df.month.value_counts()
# Out:
# Ju    429
# Ma    429
# Ja    243
# Ap    235
# No    233
# De    230
# Oc    194
# Fe    191
# Se    165
# Au    151
# Name: month, dtype: int64

# %%
df['month'].replace({'Ja':1,"Fe":2,'Ma':3,'Ap':4,'Ju':6,'Au':8,'Se':9,'Oc':10,'No':11,'De':12},inplace=True)
df
# Out:
#                                                 reviews                date  \
# 0     ✅ Trip Verified |  I had the most fantastic BA...     1st August 2023
# 1     ✅ Trip Verified |  Couldn’t book in online. Ar...      31st July 2023
# 2     ✅ Trip Verified | London Heathrow to Mumbai in...      31st July 2023
# 3     ✅ Trip Verified | Keflavík, Iceland to London ...      31st July 2023
# 4     ✅ Trip Verified | Terrible Experience with Bri...      29th July 2023
# ...                                                 ...                 ...
# 2495  Roundtrip with British Airways from Bangkok to...  12th November 2015
# 2496  Awful customer service. My wife and I have flo...  11th November 2015
# 2497  I travelled from London to Sydney via Singapor...  10th November 2015
# 2498  British Airways have just moved Cape Town flig...  10th November 2015
# 2499  Bengaluru to Heathrow. My first long haul flig...  10th November 2015
#
#              country       seat_type recommended  stars  \
# 0          Hong Kong  Business Class         yes      5
# 1     United Kingdom   Economy Class          no      3
# 2            Iceland  Business Class         yes      3
# 3            Iceland  Business Class         yes      5
# 4             Canada   Economy Class          no      5
# ...              ...             ...         ...    ...
# 2495        Thailand  Business Class          no      7
# 2496  United Kingdom  Business Class          no      3
# 2497       Australia     First Class         yes      5
# 2498  United Kingdom     First Class         yes      3
# 2499           India   Economy Class          no      3
#
#                       route type_of_traveller day  month year
# 0     Heathrow to Las Vegas    Family Leisure   1      8   23
# 1          Rome to Heathrow      Solo Leisure  31      6   23
# 2         Gatwick to Venice      Solo Leisure  31      6   23
# 3          London to Luanda    Couple Leisure  31      6   23
# 4        Denver to Heathrow    Family Leisure  29      6   23
# ...                     ...               ...  ..    ...  ...
# 2495             BKK to LHR          Business  12     11   15
# 2496        London to Tampa    Couple Leisure  11     11   15
# 2497       London to Sydney    Couple Leisure  10     11   15
# 2498             LHR to CPT    Couple Leisure  10     11   15
# 2499             BLR to LHR          Business  10     11   15
#
# [2500 rows x 11 columns]

# %%
df.drop('date',axis='columns',inplace=True)
df
# Out:
#                                                 reviews         country  \
# 0     ✅ Trip Verified |  I had the most fantastic BA...       Hong Kong
# 1     ✅ Trip Verified |  Couldn’t book in online. Ar...  United Kingdom
# 2     ✅ Trip Verified | London Heathrow to Mumbai in...         Iceland
# 3     ✅ Trip Verified | Keflavík, Iceland to London ...         Iceland
# 4     ✅ Trip Verified | Terrible Experience with Bri...          Canada
# ...                                                 ...             ...
# 2495  Roundtrip with British Airways from Bangkok to...        Thailand
# 2496  Awful customer service. My wife and I have flo...  United Kingdom
# 2497  I travelled from London to Sydney via Singapor...       Australia
# 2498  British Airways have just moved Cape Town flig...  United Kingdom
# 2499  Bengaluru to Heathrow. My first long haul flig...           India
#
#            seat_type recommended  stars                  route  \
# 0     Business Class         yes      5  Heathrow to Las Vegas
# 1      Economy Class          no      3       Rome to Heathrow
# 2     Business Class         yes      3      Gatwick to Venice
# 3     Business Class         yes      5       London to Luanda
# 4      Economy Class          no      5     Denver to Heathrow
# ...              ...         ...    ...                    ...
# 2495  Business Class          no      7             BKK to LHR
# 2496  Business Class          no      3        London to Tampa
# 2497     First Class         yes      5       London to Sydney
# 2498     First Class         yes      3             LHR to CPT
# 2499   Economy Class          no      3             BLR to LHR
#
#      type_of_traveller day  month year
# 0       Family Leisure   1      8   23
# 1         Solo Leisure  31      6   23
# 2         Solo Leisure  31      6   23
# 3       Couple Leisure  31      6   23
# 4       Family Leisure  29      6   23
# ...                ...  ..    ...  ...
# 2495          Business  12     11   15
# 2496    Couple Leisure  11     11   15
# 2497    Couple Leisure  10     11   15
# 2498    Couple Leisure  10     11   15
# 2499          Business  10     11   15
#
# [2500 rows x 10 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df['country']=label.fit_transform(df['country'])
df['seat_type']=label.fit_transform(df['seat_type'])
df['route']=label.fit_transform(df['route'])
df['type_of_traveller']=label.fit_transform(df['type_of_traveller'])
df
# Out:
#                                                 reviews  country  seat_type  \
# 0     ✅ Trip Verified |  I had the most fantastic BA...       24          0
# 1     ✅ Trip Verified |  Couldn’t book in online. Ar...       64          1
# 2     ✅ Trip Verified | London Heathrow to Mumbai in...       26          0
# 3     ✅ Trip Verified | Keflavík, Iceland to London ...       26          0
# 4     ✅ Trip Verified | Terrible Experience with Bri...        9          1
# ...                                                 ...      ...        ...
# 2495  Roundtrip with British Airways from Bangkok to...       61          0
# 2496  Awful customer service. My wife and I have flo...       64          0
# 2497  I travelled from London to Sydney via Singapor...        1          2
# 2498  British Airways have just moved Cape Town flig...       64          2
# 2499  Bengaluru to Heathrow. My first long haul flig...       27          1
#
#      recommended  stars  route  type_of_traveller day  month year
# 0            yes      5      4                  2   1      8   23
# 1             no      3      9                  3  31      6   23
# 2            yes      3      3                  3  31      6   23
# 3            yes      5      6                  1  31      6   23
# 4             no      5      2                  2  29      6   23
# ...          ...    ...    ...                ...  ..    ...  ...
# 2495          no      7      0                  0  12     11   15
# 2496          no      3      8                  1  11     11   15
# 2497         yes      5      7                  1  10     11   15
# 2498         yes      3      5                  1  10     11   15
# 2499          no      3      1                  0  10     11   15
#
# [2500 rows x 10 columns]

# %%
df['recommended'].replace({'yes':1,'no':0},inplace=True)
df
# Out:
#                                                 reviews  country  seat_type  \
# 0     ✅ Trip Verified |  I had the most fantastic BA...       24          0
# 1     ✅ Trip Verified |  Couldn’t book in online. Ar...       64          1
# 2     ✅ Trip Verified | London Heathrow to Mumbai in...       26          0
# 3     ✅ Trip Verified | Keflavík, Iceland to London ...       26          0
# 4     ✅ Trip Verified | Terrible Experience with Bri...        9          1
# ...                                                 ...      ...        ...
# 2495  Roundtrip with British Airways from Bangkok to...       61          0
# 2496  Awful customer service. My wife and I have flo...       64          0
# 2497  I travelled from London to Sydney via Singapor...        1          2
# 2498  British Airways have just moved Cape Town flig...       64          2
# 2499  Bengaluru to Heathrow. My first long haul flig...       27          1
#
#       recommended  stars  route  type_of_traveller day  month year
# 0               1      5      4                  2   1      8   23
# 1               0      3      9                  3  31      6   23
# 2               1      3      3                  3  31      6   23
# 3               1      5      6                  1  31      6   23
# 4               0      5      2                  2  29      6   23
# ...           ...    ...    ...                ...  ..    ...  ...
# 2495            0      7      0                  0  12     11   15
# 2496            0      3      8                  1  11     11   15
# 2497            1      5      7                  1  10     11   15
# 2498            1      3      5                  1  10     11   15
# 2499            0      3      1                  0  10     11   15
#
# [2500 rows x 10 columns]

# %%
df.dtypes
# Out:
# reviews              object
# country               int32
# seat_type             int32
# recommended           int64
# stars                 int64
# route                 int32
# type_of_traveller     int32
# day                  object
# month                 int64
# year                 object
# dtype: object

# %%
df['year']=df['year'].astype('int32')
df['day']=df['day'].astype('int32')
df['month']=df['month'].astype('int32')

# %%
df['recommended']=df['recommended'].astype('int32')
df['stars']=df['stars'].astype('int32')

# %%
df.dtypes
# Out:
# reviews              object
# country               int32
# seat_type             int32
# recommended           int32
# stars                 int32
# route                 int32
# type_of_traveller     int32
# day                   int32
# month                 int32
# year                  int32
# dtype: object

# %%
df.drop('reviews',axis='columns',inplace=True)
df
# Out:
#       country  seat_type  recommended  stars  route  type_of_traveller  day  \
# 0          24          0            1      5      4                  2    1
# 1          64          1            0      3      9                  3   31
# 2          26          0            1      3      3                  3   31
# 3          26          0            1      5      6                  1   31
# 4           9          1            0      5      2                  2   29
# ...       ...        ...          ...    ...    ...                ...  ...
# 2495       61          0            0      7      0                  0   12
# 2496       64          0            0      3      8                  1   11
# 2497        1          2            1      5      7                  1   10
# 2498       64          2            1      3      5                  1   10
# 2499       27          1            0      3      1                  0   10
#
#       month  year
# 0         8    23
# 1         6    23
# 2         6    23
# 3         6    23
# 4         6    23
# ...     ...   ...
# 2495     11    15
# 2496     11    15
# 2497     11    15
# 2498     11    15
# 2499     11    15
#
# [2500 rows x 9 columns]

# %%
X=df.drop('recommended',axis='columns')
y=df.recommended

# %%
from sklearn.preprocessing import MinMaxScaler
mi=MinMaxScaler()
X=mi.fit_transform(X)
X
# Out:
# array([[0.36363636, 0.        , 0.5       , ..., 0.        , 0.63636364,
#         1.        ],
#        [0.96969697, 0.33333333, 0.25      , ..., 1.        , 0.45454545,
#         1.        ],
#        [0.39393939, 0.        , 0.25      , ..., 1.        , 0.45454545,
#         1.        ],
#        ...,
#        [0.01515152, 0.66666667, 0.5       , ..., 0.3       , 0.90909091,
#         0.        ],
#        [0.96969697, 0.66666667, 0.25      , ..., 0.3       , 0.90909091,
#         0.        ],
#        [0.40909091, 0.33333333, 0.25      , ..., 0.3       , 0.90909091,
#         0.        ]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
print(X_train.shape)
# Out:
# (2000, 8)

# %%
print(X_test.shape)
# Out:
# (500, 8)

# %%
from sklearn.linear_model import LogisticRegression
lo=LogisticRegression()
lo.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
lo.score(X_test,y_test)
# Out:
# 0.666

# %%
from sklearn.tree import DecisionTreeClassifier
Do=DecisionTreeClassifier(max_leaf_nodes=150)
Do.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=150)

# %%
Do.score(X_test,y_test)
# Out:
# 0.638

# %%
from sklearn.ensemble import GradientBoostingClassifier
G=GradientBoostingClassifier(learning_rate=0.5,n_estimators=10,max_depth=3)
G.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.5, n_estimators=10)

# %%
G.score(X_test,y_test)
# Out:
# 0.66

# %%
from sklearn.ensemble import RandomForestClassifier
ro=RandomForestClassifier(n_estimators=200,max_depth=200)
ro.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=200, n_estimators=200)

# %%
ro.score(X_test,y_test)
# Out:
# 0.648

# %%
from sklearn.svm import SVC
svc=SVC(kernel='poly',C=200,degree=3)
svc.fit(X_train,y_train)
# Out:
# SVC(C=200, kernel='poly')

# %%
svc.score(X_test,y_test)
# Out:
# 0.678

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.12.0'

# %%
import tensorflow as tf
from tensorflow import keras


model=keras.Sequential([
keras.layers.Dense(8,input_shape=(8,),activation='relu'),
keras.layers.Dense(4,activation='relu'),
keras.layers.Dense(2,activation='relu'),
keras.layers.Dense(1,activation='sigmoid'),
])

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(X_train,y_train,epochs=120)
# Out:
# Epoch 1/120
# 63/63 [==============================] - 1s 3ms/step - loss: 0.7103 - accuracy: 0.5005
# Epoch 2/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6839 - accuracy: 0.6250
# Epoch 3/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6774 - accuracy: 0.6450
# Epoch 4/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6724 - accuracy: 0.6455
# Epoch 5/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6684 - accuracy: 0.6445
# Epoch 6/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6651 - accuracy: 0.6440
# Epoch 7/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6622 - accuracy: 0.6445
# Epoch 8/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6598 - accuracy: 0.6450
# Epoch 9/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6576 - accuracy: 0.6440
# Epoch 10/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6558 - accuracy: 0.6440
# Epoch 11/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6543 - accuracy: 0.6445
# Epoch 12/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6531 - accuracy: 0.6455
# Epoch 13/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6522 - accuracy: 0.6450
# Epoch 14/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6513 - accuracy: 0.6455
# Epoch 15/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6507 - accuracy: 0.6470
# Epoch 16/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6500 - accuracy: 0.6465
# Epoch 17/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6495 - accuracy: 0.6460
# Epoch 18/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6491 - accuracy: 0.6460
# Epoch 19/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6484 - accuracy: 0.6485
# Epoch 20/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6483 - accuracy: 0.6475
# Epoch 21/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6477 - accuracy: 0.6475
# Epoch 22/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6473 - accuracy: 0.6480
# Epoch 23/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6471 - accuracy: 0.6475
# Epoch 24/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6467 - accuracy: 0.6485
# Epoch 25/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6468 - accuracy: 0.6465
# Epoch 26/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6465 - accuracy: 0.6485
# Epoch 27/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6461 - accuracy: 0.6490
# Epoch 28/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6460 - accuracy: 0.6500
# Epoch 29/120
# 63/63 [==============================] - 0s 4ms/step - loss: 0.6457 - accuracy: 0.6505
# Epoch 30/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6454 - accuracy: 0.6470
# Epoch 31/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6452 - accuracy: 0.6480
# Epoch 32/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6452 - accuracy: 0.6455
# Epoch 33/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6453 - accuracy: 0.6475
# Epoch 34/120
# 63/63 [==============================] - 0s 4ms/step - loss: 0.6449 - accuracy: 0.6490
# Epoch 35/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6451 - accuracy: 0.6510
# Epoch 36/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6446 - accuracy: 0.6495
# Epoch 37/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6445 - accuracy: 0.6485
# Epoch 38/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6443 - accuracy: 0.6460
# Epoch 39/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6447 - accuracy: 0.6505
# Epoch 40/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6444 - accuracy: 0.6485
# Epoch 41/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6446 - accuracy: 0.6470
# Epoch 42/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6441 - accuracy: 0.6465
# Epoch 43/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6439 - accuracy: 0.6455
# Epoch 44/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6440 - accuracy: 0.6490
# Epoch 45/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6436 - accuracy: 0.6480
# Epoch 46/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6440 - accuracy: 0.6470
# Epoch 47/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6438 - accuracy: 0.6490
# Epoch 48/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6434 - accuracy: 0.6475
# Epoch 49/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6434 - accuracy: 0.6470
# Epoch 50/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6433 - accuracy: 0.6500
# Epoch 51/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6432 - accuracy: 0.6510
# Epoch 52/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6436 - accuracy: 0.6490
# Epoch 53/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6436 - accuracy: 0.6490
# Epoch 54/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6438 - accuracy: 0.6500
# Epoch 55/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6429 - accuracy: 0.6480
# Epoch 56/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6429 - accuracy: 0.6530
# Epoch 57/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6432 - accuracy: 0.6515
# Epoch 58/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6431 - accuracy: 0.6500
# Epoch 59/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6426 - accuracy: 0.6510
# Epoch 60/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6428 - accuracy: 0.6540
# Epoch 61/120
# 63/63 [==============================] - 0s 4ms/step - loss: 0.6428 - accuracy: 0.6510
# Epoch 62/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6427 - accuracy: 0.6500
# Epoch 63/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6423 - accuracy: 0.6500
# Epoch 64/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6424 - accuracy: 0.6490
# Epoch 65/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6421 - accuracy: 0.6500
# Epoch 66/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6419 - accuracy: 0.6520
# Epoch 67/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6422 - accuracy: 0.6530
# Epoch 68/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6420 - accuracy: 0.6515
# Epoch 69/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6418 - accuracy: 0.6525
# Epoch 70/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6421 - accuracy: 0.6515
# Epoch 71/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6417 - accuracy: 0.6510
# Epoch 72/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6417 - accuracy: 0.6545
# Epoch 73/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6419 - accuracy: 0.6500
# Epoch 74/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6420 - accuracy: 0.6530
# Epoch 75/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6416 - accuracy: 0.6520
# Epoch 76/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6418 - accuracy: 0.6535
# Epoch 77/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6418 - accuracy: 0.6535
# Epoch 78/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6416 - accuracy: 0.6530
# Epoch 79/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6414 - accuracy: 0.6545
# Epoch 80/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6412 - accuracy: 0.6530
# Epoch 81/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6415 - accuracy: 0.6535
# Epoch 82/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6412 - accuracy: 0.6560
# Epoch 83/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6417 - accuracy: 0.6525
# Epoch 84/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6413 - accuracy: 0.6530
# Epoch 85/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6408 - accuracy: 0.6555
# Epoch 86/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6413 - accuracy: 0.6545
# Epoch 87/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6414 - accuracy: 0.6545
# Epoch 88/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6410 - accuracy: 0.6565
# Epoch 89/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6411 - accuracy: 0.6525
# Epoch 90/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6408 - accuracy: 0.6540
# Epoch 91/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6410 - accuracy: 0.6535
# Epoch 92/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6407 - accuracy: 0.6540
# Epoch 93/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6410 - accuracy: 0.6555
# Epoch 94/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6406 - accuracy: 0.6545
# Epoch 95/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6407 - accuracy: 0.6545
# Epoch 96/120
# 63/63 [==============================] - 0s 4ms/step - loss: 0.6408 - accuracy: 0.6530
# Epoch 97/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6409 - accuracy: 0.6545
# Epoch 98/120
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6405 - accuracy: 0.6550
# Epoch 99/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6404 - accuracy: 0.6545
# Epoch 100/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6403 - accuracy: 0.6550
# Epoch 101/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6406 - accuracy: 0.6555
# Epoch 102/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6410 - accuracy: 0.6545
# Epoch 103/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6403 - accuracy: 0.6530
# Epoch 104/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6403 - accuracy: 0.6545
# Epoch 105/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6404 - accuracy: 0.6545
# Epoch 106/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6402 - accuracy: 0.6520
# Epoch 107/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6403 - accuracy: 0.6550
# Epoch 108/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6401 - accuracy: 0.6525
# Epoch 109/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6401 - accuracy: 0.6540
# Epoch 110/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6401 - accuracy: 0.6545
# Epoch 111/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6402 - accuracy: 0.6550
# Epoch 112/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6400 - accuracy: 0.6545
# Epoch 113/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6399 - accuracy: 0.6540
# Epoch 114/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6398 - accuracy: 0.6560
# Epoch 115/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6397 - accuracy: 0.6555
# Epoch 116/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6395 - accuracy: 0.6545
# Epoch 117/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6394 - accuracy: 0.6540
# Epoch 118/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6394 - accuracy: 0.6570
# Epoch 119/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6394 - accuracy: 0.6550
# Epoch 120/120
# 63/63 [==============================] - 0s 2ms/step - loss: 0.6393 - accuracy: 0.6550
